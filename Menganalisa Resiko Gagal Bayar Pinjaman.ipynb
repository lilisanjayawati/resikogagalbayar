# %% [markdown]
# # Menganalisis Risiko Gagal Bayar Peminjam
#
# Kali ini saya akan mencari tahu pengaruh status perkawinan seorang nasabah dan jumlah anak yang dimilikinya terhadap probabilitas gagal bayar dalam pelunasan pinjaman. Pihak bank sudah memiliki beberapa data mengenai kelayakan kredit nasabah.
#
# Laporan ini akan dipertimbangkan pada saat membuat **penilaian kredit** untuk calon nasabah. **Penilaian kredit** digunakan untuk mengevaluasi kemampuan calon peminjam untuk melunasi pinjaman mereka.

# %%
import pandas as pd
import numpy as np

# %%
try:
    df = pd.read_csv('credit_scoring_eng.csv')# Muat datanya
except:
    df = pd.read_csv('/datasets/credit_scoring_eng.csv')

# %% [markdown]
# ## Soal 1. Eksplorasi data
#
# **Deskripsi Data**
# - `children` - jumlah anak dalam keluarga
# - `days_employed` - pengalaman kerja nasabah dalam hari
# - `dob_years` - usia nasabah dalam tahun
# - `education` - tingkat pendidikan nasabah
# - `education_id` - pengidentifikasi untuk tingkat pendidikan nasabah
# - `family_status` - pengidentifikasi untuk status perkawinan nasabah
# - `family_status_id` - tanda pengenal status perkawinan
# - `gender` - jenis kelamin nasabah
# - `income_type` - jenis pekerjaan
# - `debt` - apakah nasabah memiliki hutang pembayaran pinjaman
# - `total_income` - pendapatan bulanan
# - `purpose` - tujuan mendapatkan pinjaman

# %%
df.shape# Mari kita lihat berapa banyak baris dan kolom yang dimiliki oleh dataset kita
# Out:
# (21525, 12)

# %%
df.head()# Mari tampilkan N baris pertama
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#                    purpose
# 0    purchase of the house
# 1             car purchase
# 2    purchase of the house
# 3  supplementary education
# 4        to have a wedding

# %% [markdown]
# Terdapat masalah pada kolom days_employed yang memuat nilai negatif pada hitungan hari kerja, serta kesalahan penulisan pada nilai di kolom education.

# %%
df.info()# Dapatkan informasi data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Ada 2 kolom yang memiliki nilai yang hilang, yaitu kolom days_employed dan total_income. Perlu diamati lebih lanjut lagi.

# %%
# Mari kita lihat tabel yang difilter dengan nilai yang hilang di kolom pertama yang mengandung data yang hilang
df.isnull().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# Jumlah nilai yang hilang adalah 2174. Karena total nilai adalah 21525. Perlu penyelidikan lebih lanjut untuk mengetahui apakah nilai yang hilang memang dibutuhkan atau tidak.

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt   total_income
# count      21525.000000  21525.000000   19351.000000
# mean           0.972544      0.080883   26787.568355
# std            1.420324      0.272661   16475.450632
# min            0.000000      0.000000    3306.762000
# 25%            0.000000      0.000000   16488.504500
# 50%            0.000000      0.000000   23202.870000
# 75%            1.000000      0.000000   32549.611000
# max            4.000000      1.000000  362496.645000

# %%
# Mari kita terapkan beberapa kondisi untuk memfilter data dan melihat jumlah baris dalam tabel yang telah difilter.
df[df['days_employed'].isnull() & df['total_income'].isnull()]
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 12            0            NaN         65  secondary education             1
# 26            0            NaN         41  secondary education             1
# 29            0            NaN         63  secondary education             1
# 41            0            NaN         50  secondary education             1
# 55            0            NaN         54  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21489         2            NaN         47  Secondary Education             1
# 21495         1            NaN         50  secondary education             1
# 21497         0            NaN         48    BACHELOR'S DEGREE             0
# 21502         1            NaN         42  secondary education             1
# 21510         2            NaN         28  secondary education             1
#
#            family_status  family_status_id gender    income_type  debt  \
# 12     civil partnership                 1      M        retiree     0
# 26               married                 0      M  civil servant     0
# 29             unmarried                 4      F        retiree     0
# 41               married                 0      F  civil servant     0
# 55     civil partnership                 1      F        retiree     1
# ...                  ...               ...    ...            ...   ...
# 21489            married                 0      M       business     0
# 21495  civil partnership                 1      F       employee     0
# 21497            married                 0      F       business     0
# 21502            married                 0      F       employee     0
# 21510            married                 0      F       employee     0
#
#        total_income                   purpose
# 12              NaN         to have a wedding
# 26              NaN                 education
# 29              NaN    building a real estate
# 41              NaN  second-hand car purchase
# 55              NaN         to have a wedding
# ...             ...                       ...
# 21489           NaN         purchase of a car
# 21495           NaN          wedding ceremony
# 21497           NaN       building a property
# 21502           NaN    building a real estate
# 21510           NaN              car purchase
#
# [2174 rows x 12 columns]

# %% [markdown]
# **Kesimpulan sementara**
#
# Jumlah baris yg telah difilter sudah sesuai dengan jumlah nilai yang hilang. Selanjutnya kita dapat mengisi atau menghapus nilai yang hilang tersebut.
#
# Dengan adanya hitungan persentase pada sel dibawah ini, nilai yang hilang berjumlah sekitar 10%.
#
# Saya akan memilah kembali data/nilai mana yang perlu dihapus atau diisi. Karena bisa jadi nilai yang akan dihapus justru memiliki nilai penting berkaitan dengan data lainnya.

# %%
df['days_employed'].isnull().value_counts(normalize=True)
# Out:
# False    0.899001
# True     0.100999
# Name: days_employed, dtype: float64

# %%
df['total_income'].isnull().value_counts(normalize=True)
# Out:
# False    0.899001
# True     0.100999
# Name: total_income, dtype: float64

# %%
# Mari kita periksa nasabah yang tidak memiliki data tentang karakteristik yang teridentifikasi dan kolom dengan nilai yang hilang
df_null = df[df['days_employed'].isnull() & df['total_income'].isnull()].reset_index(drop=True)

# %%
df_null
# Out:
#       children  days_employed  dob_years            education  education_id  \
# 0            0            NaN         65  secondary education             1
# 1            0            NaN         41  secondary education             1
# 2            0            NaN         63  secondary education             1
# 3            0            NaN         50  secondary education             1
# 4            0            NaN         54  secondary education             1
# ...        ...            ...        ...                  ...           ...
# 2169         2            NaN         47  Secondary Education             1
# 2170         1            NaN         50  secondary education             1
# 2171         0            NaN         48    BACHELOR'S DEGREE             0
# 2172         1            NaN         42  secondary education             1
# 2173         2            NaN         28  secondary education             1
#
#           family_status  family_status_id gender    income_type  debt  \
# 0     civil partnership                 1      M        retiree     0
# 1               married                 0      M  civil servant     0
# 2             unmarried                 4      F        retiree     0
# 3               married                 0      F  civil servant     0
# 4     civil partnership                 1      F        retiree     1
# ...                 ...               ...    ...            ...   ...
# 2169            married                 0      M       business     0
# 2170  civil partnership                 1      F       employee     0
# 2171            married                 0      F       business     0
# 2172            married                 0      F       employee     0
# 2173            married                 0      F       employee     0
#
#       total_income                   purpose
# 0              NaN         to have a wedding
# 1              NaN                 education
# 2              NaN    building a real estate
# 3              NaN  second-hand car purchase
# 4              NaN         to have a wedding
# ...            ...                       ...
# 2169           NaN         purchase of a car
# 2170           NaN          wedding ceremony
# 2171           NaN       building a property
# 2172           NaN    building a real estate
# 2173           NaN              car purchase
#
# [2174 rows x 12 columns]

# %%
df_null['education'].value_counts()# Periksalah distribusinya
# Out:
# secondary education    1408
# bachelor's degree       496
# SECONDARY EDUCATION      67
# Secondary Education      65
# some college             55
# Bachelor's Degree        25
# BACHELOR'S DEGREE        23
# primary education        19
# Some College              7
# SOME COLLEGE              7
# PRIMARY EDUCATION         1
# Primary Education         1
# Name: education, dtype: int64

# %% [markdown]
# Dikarenakan perbedaan gaya penulisan, informasi yang didapatkan dari kolom 'education' terlihat berantakan.
#
# **Kemungkinan penyebab hilangnya nilai dalam data**
#
# Saat ini masih belum bisa disimpulkan dengan pasti alasan hilangnya nilai tersebut, kita akan mengetahuinya dengan memperbaikinya terlebih dulu.

# %%
df['education'].value_counts()# Memeriksa distribusi di seluruh *dataset*
# Out:
# secondary education    13750
# bachelor's degree       4718
# SECONDARY EDUCATION      772
# Secondary Education      711
# some college             668
# BACHELOR'S DEGREE        274
# Bachelor's Degree        268
# primary education        250
# Some College              47
# SOME COLLEGE              29
# PRIMARY EDUCATION         17
# Primary Education         15
# graduate degree            4
# Graduate Degree            1
# GRADUATE DEGREE            1
# Name: education, dtype: int64

# %% [markdown]
# **Kesimpulan sementara**
#
# Apakah distribusi dalam *dataset* yang asli mirip dengan distribusi tabel yang telah difilter?
# Tidak mirip, ini berarti data yang kita miliki harus dibersihkan dan dirapikan.
#
# Mari pikirkan alasan lain yang dapat menyebabkan data hilang dan periksa apakah kita dapat menemukan pola tertentu yang dapat membuat kita berpikir bahwa hilangnya nilai-nilai tersebut tidak terjadi secara acak.

# %%
# Periksa penyebab dan pola lain yang dapat mengakibatkan nilai yang hilang
df_null
# Out:
#       children  days_employed  dob_years            education  education_id  \
# 0            0            NaN         65  secondary education             1
# 1            0            NaN         41  secondary education             1
# 2            0            NaN         63  secondary education             1
# 3            0            NaN         50  secondary education             1
# 4            0            NaN         54  secondary education             1
# ...        ...            ...        ...                  ...           ...
# 2169         2            NaN         47  Secondary Education             1
# 2170         1            NaN         50  secondary education             1
# 2171         0            NaN         48    BACHELOR'S DEGREE             0
# 2172         1            NaN         42  secondary education             1
# 2173         2            NaN         28  secondary education             1
#
#           family_status  family_status_id gender    income_type  debt  \
# 0     civil partnership                 1      M        retiree     0
# 1               married                 0      M  civil servant     0
# 2             unmarried                 4      F        retiree     0
# 3               married                 0      F  civil servant     0
# 4     civil partnership                 1      F        retiree     1
# ...                 ...               ...    ...            ...   ...
# 2169            married                 0      M       business     0
# 2170  civil partnership                 1      F       employee     0
# 2171            married                 0      F       business     0
# 2172            married                 0      F       employee     0
# 2173            married                 0      F       employee     0
#
#       total_income                   purpose
# 0              NaN         to have a wedding
# 1              NaN                 education
# 2              NaN    building a real estate
# 3              NaN  second-hand car purchase
# 4              NaN         to have a wedding
# ...            ...                       ...
# 2169           NaN         purchase of a car
# 2170           NaN          wedding ceremony
# 2171           NaN       building a property
# 2172           NaN    building a real estate
# 2173           NaN              car purchase
#
# [2174 rows x 12 columns]

# %%
df
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42    bachelor's degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F    business     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                  purpose
# 0         40620.102    purchase of the house
# 1         17932.802             car purchase
# 2         23341.752    purchase of the house
# 3         42820.568  supplementary education
# 4         25378.572        to have a wedding
# ...             ...                      ...
# 21520     35966.698     housing transactions
# 21521     24959.969        purchase of a car
# 21522     14347.610                 property
# 21523     39054.888        buying my own car
# 21524     13127.587             to buy a car
#
# [21525 rows x 12 columns]

# %% [markdown]
# Umumnya nilai yg hilang bisa berada di baris berbeda,namun yang terjadi di datasets ini bisa dilihat
# dari hasil tampilan df dan df_null diatas, bahwa nilai yang hilang pada baris tertentu di kolom days_employed,
# juga hilang pada baris yang sama di kolom total_income.

# %% [markdown]
# **Kesimpulan sementara**
#
# Nilai yang hilang pada kedua kolom memiliki jumlah yang sama dan di baris yang sama juga. Ini bisa jadi kebetulan, bisa juga karena disebabkan kesalahan atau eror saat menginput dan memindahkan data.

# %% [markdown]
# ## Transformasi data
#
# Mari kita perhatikan setiap kolom untuk melihat masalah apa yang mungkin dimiliki mereka.
#
# Saya akan mulailah dengan menghapus duplikat dan memperbaiki data tentang informasi pendidikan jika diperlukan.

# %%
# Mari kita lihat semua nilai di kolom pendidikan untuk memeriksa ejaan apa yang perlu diperbaiki
df['education'].value_counts()
# Out:
# secondary education    13750
# bachelor's degree       4718
# SECONDARY EDUCATION      772
# Secondary Education      711
# some college             668
# BACHELOR'S DEGREE        274
# Bachelor's Degree        268
# primary education        250
# Some College              47
# SOME COLLEGE              29
# PRIMARY EDUCATION         17
# Primary Education         15
# graduate degree            4
# GRADUATE DEGREE            1
# Graduate Degree            1
# Name: education, dtype: int64

# %%
df['education'] = df['education'].str.lower()# Perbaiki pencatatan jika diperlukan

# %%
df['education'].value_counts()
# Periksa semua nilai di kolom untuk memastikan bahwa kita telah memperbaikinya dengan tepat
# Out:
# secondary education    15233
# bachelor's degree       5260
# some college             744
# primary education        282
# graduate degree            6
# Name: education, dtype: int64

# %% [markdown]
# Saya melihat banyaknya kesalahan dalam penulisan di kolom 'education', seperti perbedaan pada huruf kecil dan besar padahal nama status pendidikannya sama.
# Maka dari itu, saya mengubahnya menjadi huruf kecil semua dengan menggunakan str.lower()

# %%
df['children'].value_counts()# Mari kita lihat distribusi nilai pada kolom `children'
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# Tidak mungkin ada jumlah anak sebanyak -1, dan kecil juga kemungkinan mempunyai jumlah anak sebanyak 20. Saya akan menganggap masalah ini sebagai kesalahan dalam penginputan data, maka jumlah anak -1 akan saya ganti dengan 0, dan jumlah anak 20 akan saya ganti dengan 2.

# %%
# memperbaiki data berdasarkan keputusan
df['children'] = df['children'].replace({-1 : 0, 20 : 2})

# %%
# Periksa kembali kolom `children` untuk memastikan bahwa semuanya telah diperbaiki
df['children'].value_counts()
# Out:
# 0    14196
# 1     4818
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %%
df['days_employed'].value_counts()
# Out:
# -327.685916     1
# -1580.622577    1
# -4122.460569    1
# -2828.237691    1
# -2636.090517    1
#                ..
# -7120.517564    1
# -2146.884040    1
# -881.454684     1
# -794.666350     1
# -3382.113891    1
# Name: days_employed, Length: 19351, dtype: int64

# %%
len(df.loc[df['days_employed'] < 0]) / len(df)
# Temukan data yang bermasalah di `days_employed`, jika memang terdapat masalah, dan hitung persentasenya
# Persentase masalahnya sekitar 70% dan nilai yang ada dalam minus.
# Out:
# 0.7389547038327526

# %% [markdown]
# Hal yang menurut saya sangat mungkin terjadi adalah kesalahan dalam penginputan. Mengingat jumlah data yang banyak, hal ini sangat mungkin dapat terjadi. Nilai pada kolom 'days_employed' tidak seharusnya ada minus karena nilainya bukanlah perhitungan minus seperti kerugian.

# %%
df['days_employed'] = df['days_employed'].abs()# Atasi nilai yang bermasalah, jika ada

# %%
# Periksa hasilnya - pastikan bahwa masalahnya telah diperbaiki
df['days_employed'].value_counts()
# Out:
# 142.276217       1
# 1849.622944      1
# 886.253127       1
# 2539.534295      1
# 390574.985524    1
#                 ..
# 1394.302246      1
# 2325.720832      1
# 4086.407828      1
# 1259.497032      1
# 1636.419775      1
# Name: days_employed, Length: 19351, dtype: int64

# %%
df['dob_years'].value_counts(normalize=True)# Periksa `dob_years` untuk nilai yang mencurigakan dan hitung persentasenya
# Out:
# 35    0.028664
# 40    0.028293
# 41    0.028200
# 34    0.028014
# 38    0.027782
# 42    0.027735
# 33    0.026992
# 39    0.026620
# 31    0.026016
# 36    0.025784
# 44    0.025412
# 29    0.025319
# 30    0.025087
# 48    0.024994
# 37    0.024948
# 50    0.023879
# 43    0.023833
# 32    0.023693
# 49    0.023600
# 28    0.023368
# 45    0.023089
# 27    0.022904
# 56    0.022625
# 52    0.022485
# 47    0.022300
# 54    0.022253
# 46    0.022067
# 58    0.021417
# 57    0.021370
# 53    0.021324
# 51    0.020813
# 59    0.020627
# 55    0.020581
# 26    0.018955
# 60    0.017515
# 25    0.016585
# 61    0.016492
# 62    0.016353
# 63    0.012497
# 64    0.012311
# 24    0.012265
# 23    0.011800
# 65    0.009013
# 66    0.008502
# 22    0.008502
# 67    0.007758
# 21    0.005157
# 0     0.004692
# 68    0.004599
# 69    0.003949
# 70    0.003020
# 71    0.002695
# 20    0.002369
# 72    0.001533
# 19    0.000650
# 73    0.000372
# 74    0.000279
# 75    0.000046
# Name: dob_years, dtype: float64

# %% [markdown]
# Ada usia 0 dan 70 tahun ke atas. Tidak mungkin ada orang berusia 0 tahun yang mengajukan kredit, sedangkan dengan orang berusia 70 tahun keatas, umumnya lebih sulit mendapatkan kredit karena faktor umur yang terlalu tua. Tetapi masih ada kemungkinan pengajuannya diterima karena pertimbangan memiliki passive income dan lainnya.

# %%
# Atasi masalah pada kolom `dob_years`, jika terdapat masalah
df['dob_years'] = df[df['dob_years'] != 0]['dob_years']

# %%
# Periksa hasilnya - pastikan bahwa masalahnya telah diperbaiki
df['dob_years'].value_counts()
# Out:
# 35.0    617
# 40.0    609
# 41.0    607
# 34.0    603
# 38.0    598
# 42.0    597
# 33.0    581
# 39.0    573
# 31.0    560
# 36.0    555
# 44.0    547
# 29.0    545
# 30.0    540
# 48.0    538
# 37.0    537
# 50.0    514
# 43.0    513
# 32.0    510
# 49.0    508
# 28.0    503
# 45.0    497
# 27.0    493
# 56.0    487
# 52.0    484
# 47.0    480
# 54.0    479
# 46.0    475
# 58.0    461
# 57.0    460
# 53.0    459
# 51.0    448
# 59.0    444
# 55.0    443
# 26.0    408
# 60.0    377
# 25.0    357
# 61.0    355
# 62.0    352
# 63.0    269
# 64.0    265
# 24.0    264
# 23.0    254
# 65.0    194
# 66.0    183
# 22.0    183
# 67.0    167
# 21.0    111
# 68.0     99
# 69.0     85
# 70.0     65
# 71.0     58
# 20.0     51
# 72.0     33
# 19.0     14
# 73.0      8
# 74.0      6
# 75.0      1
# Name: dob_years, dtype: int64

# %%
df['family_status'].value_counts()# Mari kita lihat nilai untuk kolom ini
# Out:
# married              12380
# civil partnership     4177
# unmarried             2813
# divorced              1195
# widow / widower        960
# Name: family_status, dtype: int64

# %%
df['gender'].value_counts()# Mari kita liat nilai dalam kolom ini
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %%
df['gender'] = df[df['gender'] != 'XNA']['gender'] #Atasi nilai-nilai yang bermasalah, jika ada

# %%
# Periksa hasilnya - pastikan bahwa masalahnya telah diperbaiki
df['gender'].value_counts()
# Out:
# F    14236
# M     7288
# Name: gender, dtype: int64

# %% [markdown]
# Seperti yang bisa dilihat pada hasil pemeriksaan di atas, kolom gender memiliki nilai 'XNA', yang berarti tidak diketahui apakah pengisi data bergender Female atau Male.
# Saya memilih untuk menghapusnya karena 'XNA' tidak bisa dipindahkan ke 'F' ataupun 'M'.

# %%
df['income_type'].value_counts()# Mari kita lihat nilai dalam kolom ini
# Out:
# employee                       11119
# business                        5085
# retiree                         3856
# civil servant                   1459
# entrepreneur                       2
# unemployed                         2
# paternity / maternity leave        1
# student                            1
# Name: income_type, dtype: int64

# %%
df['income_type'] = df[df['income_type'] != 'unemployed']['income_type']# Atasi nilai yang bermasalah, jika ada

# Unemployed dihapus karena orang yang sedang menganggur berarti tidak memiliki penghasilan,
# maka dari itu dianggap tidak bisa mengajukan kredit.

# %%
# Periksa hasilnya - pastikan bahwa masalahnya telah diperbaiki
df['income_type'].value_counts()
# Out:
# employee                       11119
# business                        5085
# retiree                         3856
# civil servant                   1459
# entrepreneur                       2
# paternity / maternity leave        1
# student                            1
# Name: income_type, dtype: int64

# %% [markdown]
# Diantara semua 'income type' ada nilai 'unemployed'. Menurut saya, nilai ini perlu dihapus karena seperti penjelasan yang tertulis di atas, orang yang sedang tidak bekerja berarti tidak memiliki penghasilan, tidak berstatus pelajar dan dianggap tidak dapat melakukan pembayaran kredit nantinya.
# Berbeda dengan 'student', dari hasil research yang saya lakukan, orang yang berstatus pelajar dapat mengajukan kredit selama ia memiliki atau dapat menunjukkan bukti memiliki penghasilan dari hasil kerja part-time ataupun memiliki wali yang berumur diatas 21 tahun (yang memiliki penghasilan stabil dan akan bertanggung jawab dalam kegagalan pembayaran kredit).

# %%
df['purpose'].value_counts()
# Out:
# wedding ceremony                            797
# having a wedding                            777
# to have a wedding                           774
# real estate transactions                    676
# buy commercial real estate                  664
# buying property for renting out             653
# housing transactions                        653
# transactions with commercial real estate    651
# purchase of the house                       647
# housing                                     647
# purchase of the house for my family         641
# construction of own property                635
# property                                    634
# transactions with my real estate            630
# building a real estate                      626
# buy real estate                             624
# building a property                         620
# purchase of my own house                    620
# housing renovation                          612
# buy residential real estate                 607
# buying my own car                           505
# going to university                         496
# car                                         495
# second-hand car purchase                    489
# to own a car                                480
# buying a second-hand car                    479
# cars                                        478
# to buy a car                                472
# car purchase                                462
# supplementary education                     462
# purchase of a car                           455
# university education                        453
# education                                   447
# to get a supplementary education            447
# getting an education                        443
# profile education                           436
# getting higher education                    426
# to become educated                          412
# Name: purpose, dtype: int64

# %%
# merapikan value yang mirip atau tujuan yang sama untuk pengajuan kredit
def categorize_purpose(row):
    if 'car' in row:
      return 'car'
    elif 'hous' in row or 'prop' in row or 'real est' in row:
      return 'property'
    elif 'educ' in row or 'uni' in row:
      return 'education'
    else:
      return 'wedding'


df['purpose'] = df['purpose'].apply(categorize_purpose)

# %%
# mengecek kembali value dalam kolom purpose
df['purpose'].value_counts()
# Out:
# property     10840
# car           4315
# education     4022
# wedding       2348
# Name: purpose, dtype: int64

# %% [markdown]
# Anomali yang dapat dilihat pada kolom 'purpose' adalah kemiripan penulisan yang sebenarnya memiliki tujuan yang sama.
# Saya merapikan nilai-nilai tersebut dengan membuat fungsi yang mengategorikan nilai yang sama dalam satu kelompok.

# %%
df.duplicated().sum()# Periksa duplikat
# Out:
# 341

# %% [markdown]
# Jumlah duplikat yang ada pada data yaitu 341, dan akan diperbaiki pada kolom dibawah.

# %%
df = df.drop_duplicates()# Atasi duplikat, jika ada

# %%
# Lakukan pemeriksaan terakhir untuk mengecek apakah kita memiliki duplikat
df.duplicated().sum()
# Out:
# 0

# %%
# Periksa ukuran dataset yang sekarang Anda miliki setelah manipulasi pertama yang Anda lakukan
df.shape
# Out:
# (21184, 12)

# %% [markdown]
# Pertama, jumlah dataset telah berubah dari 21525 baris menjadi 21184 baris. Perubahan ini dihasilkan dari penghapusan duplikat yang ada sebanyak 341.

# %% [markdown]
# # Bekerja dengan nilai yang hilang

# %%
# Temukan dictionary
df.to_dict('index')
# Out:
# {0: {'children': 1,
#   'days_employed': 8437.673027760233,
#   'dob_years': 42.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 40620.102,
#   'purpose': 'property'},
#  1: {'children': 1,
#   'days_employed': 4024.803753850451,
#   'dob_years': 36.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17932.802,
#   'purpose': 'car'},
#  2: {'children': 0,
#   'days_employed': 5623.422610230956,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23341.752,
#   'purpose': 'property'},
#  3: {'children': 3,
#   'days_employed': 4124.747206540018,
#   'dob_years': 32.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 42820.568,
#   'purpose': 'education'},
#  4: {'children': 0,
#   'days_employed': 340266.07204682194,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 25378.572,
#   'purpose': 'wedding'},
#  5: {'children': 0,
#   'days_employed': 926.1858308789184,
#   'dob_years': 27.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 40922.17,
#   'purpose': 'property'},
#  6: {'children': 0,
#   'days_employed': 2879.202052139952,
#   'dob_years': 43.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 38484.156,
#   'purpose': 'property'},
#  7: {'children': 0,
#   'days_employed': 152.7795691752705,
#   'dob_years': 50.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 21731.829,
#   'purpose': 'education'},
#  8: {'children': 2,
#   'days_employed': 6929.865298973741,
#   'dob_years': 35.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 15337.093,
#   'purpose': 'wedding'},
#  9: {'children': 0,
#   'days_employed': 2188.7564450779378,
#   'dob_years': 41.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23108.15,
#   'purpose': 'property'},
#  10: {'children': 2,
#   'days_employed': 4171.483646903305,
#   'dob_years': 36.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 18230.959,
#   'purpose': 'property'},
#  11: {'children': 0,
#   'days_employed': 792.7018870609315,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 12331.077,
#   'purpose': 'property'},
#  12: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 65.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'wedding'},
#  13: {'children': 0,
#   'days_employed': 1846.6419410560736,
#   'dob_years': 54.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 20873.317,
#   'purpose': 'car'},
#  14: {'children': 0,
#   'days_employed': 1844.9561821875543,
#   'dob_years': 56.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 1,
#   'total_income': 26420.466,
#   'purpose': 'property'},
#  15: {'children': 1,
#   'days_employed': 972.3644189900732,
#   'dob_years': 26.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 18691.345,
#   'purpose': 'property'},
#  16: {'children': 0,
#   'days_employed': 1719.9342261530542,
#   'dob_years': 35.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 46272.433,
#   'purpose': 'property'},
#  17: {'children': 0,
#   'days_employed': 2369.999720209008,
#   'dob_years': 33.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 14465.694,
#   'purpose': 'property'},
#  18: {'children': 0,
#   'days_employed': 400281.1369125588,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 9091.804,
#   'purpose': 'car'},
#  19: {'children': 0,
#   'days_employed': 10038.818548915877,
#   'dob_years': 48.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 38852.977,
#   'purpose': 'car'},
#  20: {'children': 1,
#   'days_employed': 1311.6041664289485,
#   'dob_years': 36.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 33528.422999999995,
#   'purpose': 'property'},
#  21: {'children': 1,
#   'days_employed': 253.68516578402495,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 21089.953,
#   'purpose': 'car'},
#  22: {'children': 1,
#   'days_employed': 1766.6441376815046,
#   'dob_years': 24.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23948.983,
#   'purpose': 'car'},
#  23: {'children': 0,
#   'days_employed': 272.9813850334044,
#   'dob_years': 21.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 20522.515,
#   'purpose': 'wedding'},
#  24: {'children': 1,
#   'days_employed': 338551.95291136915,
#   'dob_years': 57.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 46487.558,
#   'purpose': 'property'},
#  25: {'children': 0,
#   'days_employed': 363548.4893483957,
#   'dob_years': 67.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 8818.041,
#   'purpose': 'property'},
#  26: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 41.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  27: {'children': 0,
#   'days_employed': 529.1916346594236,
#   'dob_years': 28.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 49415.837,
#   'purpose': 'property'},
#  28: {'children': 1,
#   'days_employed': 717.2743239418727,
#   'dob_years': 26.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 30058.118,
#   'purpose': 'property'},
#  29: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 63.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  30: {'children': 1,
#   'days_employed': 335581.6685149753,
#   'dob_years': 62.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 27432.971,
#   'purpose': 'property'},
#  31: {'children': 0,
#   'days_employed': 1682.08343808475,
#   'dob_years': 47.0,
#   'education': 'primary education',
#   'education_id': 3,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 44077.71,
#   'purpose': 'property'},
#  32: {'children': 0,
#   'days_employed': 4649.910831728614,
#   'dob_years': 34.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 22249.194,
#   'purpose': 'wedding'},
#  33: {'children': 0,
#   'days_employed': 1548.63754364046,
#   'dob_years': 48.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 25159.326,
#   'purpose': 'property'},
#  34: {'children': 0,
#   'days_employed': 4488.067031277062,
#   'dob_years': 35.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 16745.672,
#   'purpose': 'property'},
#  35: {'children': 0,
#   'days_employed': 394021.0721837952,
#   'dob_years': 68.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 12448.908,
#   'purpose': 'wedding'},
#  36: {'children': 0,
#   'days_employed': 176.21668833712155,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 22212.904,
#   'purpose': 'car'},
#  37: {'children': 0,
#   'days_employed': 6448.810859676204,
#   'dob_years': 43.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 24660.621,
#   'purpose': 'car'},
#  38: {'children': 0,
#   'days_employed': 597.8818273051091,
#   'dob_years': 25.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 30759.568,
#   'purpose': 'education'},
#  39: {'children': 0,
#   'days_employed': 650.5877964026586,
#   'dob_years': 31.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 120678.528,
#   'purpose': 'education'},
#  40: {'children': 0,
#   'days_employed': 1030.3626056014652,
#   'dob_years': 30.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 22858.493,
#   'purpose': 'property'},
#  41: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 50.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'car'},
#  42: {'children': 0,
#   'days_employed': 1257.4961901986044,
#   'dob_years': 20.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 13130.414,
#   'purpose': 'education'},
#  43: {'children': 0,
#   'days_employed': 4375.681384360526,
#   'dob_years': 43.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 43673.141,
#   'purpose': 'car'},
#  44: {'children': 1,
#   'days_employed': 1362.0417275002387,
#   'dob_years': 26.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 16124.879,
#   'purpose': 'car'},
#  45: {'children': 1,
#   'days_employed': 1039.4517405766287,
#   'dob_years': 49.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17021.747,
#   'purpose': 'education'},
#  46: {'children': 2,
#   'days_employed': 2262.712303593806,
#   'dob_years': 37.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 29229.194,
#   'purpose': 'car'},
#  47: {'children': 1,
#   'days_employed': 2689.1372742032745,
#   'dob_years': 33.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 57004.465,
#   'purpose': 'wedding'},
#  48: {'children': 0,
#   'days_employed': 3341.0678863600638,
#   'dob_years': 45.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 25930.483,
#   'purpose': 'property'},
#  49: {'children': 0,
#   'days_employed': 1181.443228272809,
#   'dob_years': 54.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 7134.689,
#   'purpose': 'car'},
#  50: {'children': 0,
#   'days_employed': 353731.4323382981,
#   'dob_years': 63.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 14774.837,
#   'purpose': 'car'},
#  51: {'children': 1,
#   'days_employed': 6953.631654563154,
#   'dob_years': 50.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 32511.949,
#   'purpose': 'wedding'},
#  52: {'children': 1,
#   'days_employed': 3554.6715257531628,
#   'dob_years': 28.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 8439.428,
#   'purpose': 'education'},
#  53: {'children': 0,
#   'days_employed': 4219.88338560805,
#   'dob_years': 61.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 49832.576,
#   'purpose': 'property'},
#  54: {'children': 0,
#   'days_employed': 3480.072792773725,
#   'dob_years': 27.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 14758.21,
#   'purpose': 'car'},
#  55: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 54.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 1,
#   'total_income': nan,
#   'purpose': 'wedding'},
#  56: {'children': 0,
#   'days_employed': 370145.0872371805,
#   'dob_years': 64.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 23862.567000000006,
#   'purpose': 'education'},
#  57: {'children': 0,
#   'days_employed': 2424.809748937992,
#   'dob_years': 44.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 9378.625,
#   'purpose': 'education'},
#  58: {'children': 0,
#   'days_employed': 335.31863038428764,
#   'dob_years': 36.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 66304.672,
#   'purpose': 'property'},
#  59: {'children': 0,
#   'days_employed': 4341.7867754100425,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 41819.121,
#   'purpose': 'property'},
#  60: {'children': 1,
#   'days_employed': 2534.462390327333,
#   'dob_years': 48.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 20784.365,
#   'purpose': 'education'},
#  61: {'children': 0,
#   'days_employed': 2986.20212028634,
#   'dob_years': 42.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 27837.996,
#   'purpose': 'property'},
#  62: {'children': 0,
#   'days_employed': 7845.6492334208915,
#   'dob_years': 48.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 69662.11099999999,
#   'purpose': 'education'},
#  63: {'children': 0,
#   'days_employed': 1182.5477437277514,
#   'dob_years': 45.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17600.698,
#   'purpose': 'property'},
#  64: {'children': 0,
#   'days_employed': 118.89141142450092,
#   'dob_years': 35.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 45264.075,
#   'purpose': 'car'},
#  65: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 21.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  66: {'children': 0,
#   'days_employed': 916.4288292557608,
#   'dob_years': 28.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23234.324,
#   'purpose': 'education'},
#  67: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 52.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  68: {'children': 2,
#   'days_employed': 2152.475526346754,
#   'dob_years': 46.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 94731.434,
#   'purpose': 'property'},
#  69: {'children': 0,
#   'days_employed': 779.2284491479346,
#   'dob_years': 23.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 14599.529,
#   'purpose': 'property'},
#  70: {'children': 1,
#   'days_employed': 2802.2266713967297,
#   'dob_years': 28.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 33209.835,
#   'purpose': 'property'},
#  71: {'children': 0,
#   'days_employed': 338113.5298924872,
#   'dob_years': 62.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 7028.751,
#   'purpose': 'car'},
#  72: {'children': 1,
#   'days_employed': nan,
#   'dob_years': 32.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  73: {'children': 0,
#   'days_employed': 1631.9394026219366,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 15671.495,
#   'purpose': 'education'},
#  74: {'children': 1,
#   'days_employed': 5110.54370925475,
#   'dob_years': 45.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 12982.845,
#   'purpose': 'property'},
#  75: {'children': 1,
#   'days_employed': 2953.151947577933,
#   'dob_years': 38.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 13109.661,
#   'purpose': 'property'},
#  76: {'children': 1,
#   'days_employed': 2252.1927219941026,
#   'dob_years': 44.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23838.725,
#   'purpose': 'car'},
#  77: {'children': 0,
#   'days_employed': 726.9437706256638,
#   'dob_years': 43.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 22535.036,
#   'purpose': 'car'},
#  78: {'children': 0,
#   'days_employed': 359722.94507371227,
#   'dob_years': 61.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 28020.423,
#   'purpose': 'car'},
#  79: {'children': 0,
#   'days_employed': 3278.296751179717,
#   'dob_years': 27.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 40589.074,
#   'purpose': 'car'},
#  80: {'children': 0,
#   'days_employed': 127.33494240597255,
#   'dob_years': 25.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 13238.466,
#   'purpose': 'car'},
#  81: {'children': 0,
#   'days_employed': 204.6731655316556,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17733.314,
#   'purpose': 'education'},
#  82: {'children': 2,
#   'days_employed': nan,
#   'dob_years': 50.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  83: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 52.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  84: {'children': 0,
#   'days_employed': 7125.21502761462,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 40945.468,
#   'purpose': 'property'},
#  85: {'children': 0,
#   'days_employed': 275.99384748839213,
#   'dob_years': 30.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 8659.769,
#   'purpose': 'education'},
#  86: {'children': 0,
#   'days_employed': 383933.5496643384,
#   'dob_years': 64.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 38885.353,
#   'purpose': 'wedding'},
#  87: {'children': 0,
#   'days_employed': 337659.5350035947,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 11898.217,
#   'purpose': 'property'},
#  88: {'children': 0,
#   'days_employed': 373129.7896543124,
#   'dob_years': 63.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 33099.576,
#   'purpose': 'wedding'},
#  89: {'children': 0,
#   'days_employed': 72.62578520446468,
#   'dob_years': 42.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 7914.227,
#   'purpose': 'car'},
#  90: {'children': 2,
#   'days_employed': nan,
#   'dob_years': 35.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  91: {'children': 2,
#   'days_employed': 5010.9974361252725,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 24941.897,
#   'purpose': 'property'},
#  92: {'children': 1,
#   'days_employed': 1669.2796814947967,
#   'dob_years': 40.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 30623.674,
#   'purpose': 'wedding'},
#  93: {'children': 1,
#   'days_employed': 1446.6225418245374,
#   'dob_years': 32.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 52982.334,
#   'purpose': 'car'},
#  94: {'children': 1,
#   'days_employed': nan,
#   'dob_years': 34.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'wedding'},
#  95: {'children': 0,
#   'days_employed': 541.8322411633181,
#   'dob_years': 51.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 15070.06,
#   'purpose': 'car'},
#  96: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 44.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  97: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 47.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  98: {'children': 0,
#   'days_employed': 364906.2057355492,
#   'dob_years': 54.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 31953.168,
#   'purpose': 'property'},
#  99: {'children': 0,
#   'days_employed': 346541.6188949218,
#   'dob_years': nan,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 11406.643999999998,
#   'purpose': 'car'},
#  100: {'children': 0,
#   'days_employed': 605.0264409707586,
#   'dob_years': 49.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 28221.581,
#   'purpose': 'property'},
#  101: {'children': 0,
#   'days_employed': 391558.9618490568,
#   'dob_years': 65.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 25275.278,
#   'purpose': 'car'},
#  102: {'children': 0,
#   'days_employed': 1377.4472350796152,
#   'dob_years': 51.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 20273.056,
#   'purpose': 'car'},
#  103: {'children': 1,
#   'days_employed': 888.2833470851367,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 22757.038,
#   'purpose': 'property'},
#  104: {'children': 0,
#   'days_employed': 366323.6494289441,
#   'dob_years': 59.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 26173.112,
#   'purpose': 'property'},
#  105: {'children': 0,
#   'days_employed': 2098.6262962257147,
#   'dob_years': 62.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 12301.47,
#   'purpose': 'property'},
#  106: {'children': 1,
#   'days_employed': 300.64259328925505,
#   'dob_years': 29.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 27499.477000000006,
#   'purpose': 'education'},
#  107: {'children': 0,
#   'days_employed': 1493.4491168729676,
#   'dob_years': 24.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 32478.203,
#   'purpose': 'property'},
#  108: {'children': 2,
#   'days_employed': 753.4670420858772,
#   'dob_years': 33.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 28808.28,
#   'purpose': 'car'},
#  109: {'children': 0,
#   'days_employed': 2147.472607702785,
#   'dob_years': 59.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17222.988,
#   'purpose': 'education'},
#  110: {'children': 0,
#   'days_employed': 413.9826020927449,
#   'dob_years': 41.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 18968.257,
#   'purpose': 'property'},
#  111: {'children': 0,
#   'days_employed': 12930.541677797675,
#   'dob_years': 61.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 27823.459,
#   'purpose': 'property'},
#  112: {'children': 1,
#   'days_employed': 1841.3580944791947,
#   'dob_years': 28.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 44949.489,
#   'purpose': 'property'},
#  113: {'children': 0,
#   'days_employed': 6083.9947296293385,
#   'dob_years': 52.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 19304.81600000001,
#   'purpose': 'education'},
#  114: {'children': 0,
#   'days_employed': 1599.8791614370475,
#   'dob_years': 26.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 22955.474,
#   'purpose': 'property'},
#  115: {'children': 1,
#   'days_employed': 2523.847898226973,
#   'dob_years': 38.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 15655.723999999998,
#   'purpose': 'property'},
#  116: {'children': 1,
#   'days_employed': 540.0384252136863,
#   'dob_years': 50.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 13338.611,
#   'purpose': 'property'},
#  117: {'children': 0,
#   'days_employed': 3817.113294534001,
#   'dob_years': 41.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 28636.021,
#   'purpose': 'car'},
#  118: {'children': 2,
#   'days_employed': 2774.655137092032,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 18171.554,
#   'purpose': 'wedding'},
#  119: {'children': 0,
#   'days_employed': 382189.12905557256,
#   'dob_years': 60.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 5045.56,
#   'purpose': 'property'},
#  120: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 46.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  121: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 29.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'car'},
#  122: {'children': 0,
#   'days_employed': 171.1624207214407,
#   'dob_years': 55.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 16580.491,
#   'purpose': 'car'},
#  123: {'children': 2,
#   'days_employed': 5718.70890108714,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 13422.851,
#   'purpose': 'property'},
#  124: {'children': 0,
#   'days_employed': 1080.514782425162,
#   'dob_years': 38.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 28007.428,
#   'purpose': 'property'},
#  125: {'children': 0,
#   'days_employed': 191.1467457844417,
#   'dob_years': 64.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 29825.399,
#   'purpose': 'wedding'},
#  126: {'children': 1,
#   'days_employed': 2471.5485518184228,
#   'dob_years': 49.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 54322.778,
#   'purpose': 'property'},
#  127: {'children': 0,
#   'days_employed': 5229.55206892918,
#   'dob_years': 43.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 32524.736,
#   'purpose': 'property'},
#  128: {'children': 0,
#   'days_employed': 379035.9206190428,
#   'dob_years': 67.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 17973.086,
#   'purpose': 'car'},
#  129: {'children': 0,
#   'days_employed': 361010.32134996407,
#   'dob_years': 61.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 16583.189,
#   'purpose': 'car'},
#  130: {'children': 0,
#   'days_employed': 897.3228055367267,
#   'dob_years': 42.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 15335.319,
#   'purpose': 'property'},
#  131: {'children': 0,
#   'days_employed': 639.5647075616622,
#   'dob_years': 58.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 11782.014,
#   'purpose': 'education'},
#  132: {'children': 1,
#   'days_employed': 1306.4284560155902,
#   'dob_years': 45.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 39396.479,
#   'purpose': 'car'},
#  133: {'children': 0,
#   'days_employed': 344507.39278483123,
#   'dob_years': 64.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 12647.624,
#   'purpose': 'education'},
#  134: {'children': 1,
#   'days_employed': 4171.107677064886,
#   'dob_years': 46.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 26562.526,
#   'purpose': 'property'},
#  135: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 27.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  136: {'children': 0,
#   'days_employed': 357880.1593788016,
#   'dob_years': 60.0,
#   'education': 'primary education',
#   'education_id': 3,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 18099.872,
#   'purpose': 'property'},
#  137: {'children': 1,
#   'days_employed': 1910.0375923185568,
#   'dob_years': 28.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 43107.834,
#   'purpose': 'wedding'},
#  138: {'children': 0,
#   'days_employed': 2572.053172717263,
#   'dob_years': 43.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 19172.425,
#   'purpose': 'property'},
#  139: {'children': 0,
#   'days_employed': 1765.5573866944574,
#   'dob_years': 29.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 31509.132,
#   'purpose': 'property'},
#  140: {'children': 0,
#   'days_employed': 3017.782065456124,
#   'dob_years': 24.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 16337.758,
#   'purpose': 'property'},
#  141: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'wedding'},
#  142: {'children': 0,
#   'days_employed': 347947.8355073804,
#   'dob_years': 54.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 17324.903000000002,
#   'purpose': 'car'},
#  143: {'children': 0,
#   'days_employed': 1893.2998286398856,
#   'dob_years': 48.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 24171.11,
#   'purpose': 'property'},
#  144: {'children': 1,
#   'days_employed': 2105.382664335544,
#   'dob_years': 45.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 45479.693,
#   'purpose': 'car'},
#  145: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 62.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  146: {'children': 0,
#   'days_employed': 1302.0260419746796,
#   'dob_years': 46.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 15793.557,
#   'purpose': 'property'},
#  147: {'children': 0,
#   'days_employed': 5772.479895574409,
#   'dob_years': 47.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 1,
#   'total_income': 11925.616000000002,
#   'purpose': 'property'},
#  148: {'children': 0,
#   'days_employed': 5050.292839852283,
#   'dob_years': 37.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 23225.474,
#   'purpose': 'car'},
#  149: {'children': 0,
#   'days_employed': 2664.273168317157,
#   'dob_years': nan,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 11228.23,
#   'purpose': 'property'},
#  150: {'children': 0,
#   'days_employed': 393711.519922678,
#   'dob_years': 71.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 27854.127,
#   'purpose': 'wedding'},
#  151: {'children': 0,
#   'days_employed': 896.462371368615,
#   'dob_years': 37.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 74094.397,
#   'purpose': 'wedding'},
#  152: {'children': 1,
#   'days_employed': 3597.776387865821,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 6542.581,
#   'purpose': 'property'},
#  153: {'children': 1,
#   'days_employed': 132.74853603066168,
#   'dob_years': 20.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 1,
#   'total_income': 21560.12,
#   'purpose': 'property'},
#  154: {'children': 1,
#   'days_employed': 1803.9306052678608,
#   'dob_years': 41.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 22898.133,
#   'purpose': 'property'},
#  155: {'children': 0,
#   'days_employed': 1208.5961786776136,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 11326.133999999998,
# ...
#   'purpose': 'education'},
#  948: {'children': 0,
#   'days_employed': 333508.0559734784,
#   'dob_years': 57.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 27439.356,
#   'purpose': 'education'},
#  949: {'children': 0,
#   'days_employed': 2215.7957509732128,
#   'dob_years': 35.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 33482.199,
#   'purpose': 'wedding'},
#  950: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 51.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'car'},
#  951: {'children': 2,
#   'days_employed': 5687.015869657455,
#   'dob_years': 43.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 14577.595,
#   'purpose': 'property'},
#  952: {'children': 0,
#   'days_employed': 581.2458950545381,
#   'dob_years': 33.0,
#   'education': 'some college',
#   'education_id': 2,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 21983.759,
#   'purpose': 'car'},
#  953: {'children': 0,
#   'days_employed': 2487.336761357727,
#   'dob_years': 47.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 19991.388,
#   'purpose': 'property'},
#  954: {'children': 0,
#   'days_employed': 370949.6423606032,
#   'dob_years': 58.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 26232.11,
#   'purpose': 'property'},
#  955: {'children': 0,
#   'days_employed': 377.0596524195704,
#   'dob_years': 53.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 12759.696000000002,
#   'purpose': 'car'},
#  956: {'children': 0,
#   'days_employed': 1094.705699831038,
#   'dob_years': 34.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 12684.185,
#   'purpose': 'car'},
#  957: {'children': 0,
#   'days_employed': 727.2024485873619,
#   'dob_years': 33.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 37426.098,
#   'purpose': 'property'},
#  958: {'children': 0,
#   'days_employed': 5125.978706740592,
#   'dob_years': 55.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 41732.125,
#   'purpose': 'property'},
#  959: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 25.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  960: {'children': 2,
#   'days_employed': 1774.559168054482,
#   'dob_years': 41.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 14791.766,
#   'purpose': 'education'},
#  961: {'children': 1,
#   'days_employed': 361343.15198882704,
#   'dob_years': 54.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 30400.893,
#   'purpose': 'property'},
#  962: {'children': 0,
#   'days_employed': 389157.02643454383,
#   'dob_years': 62.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 24028.669,
#   'purpose': 'property'},
#  963: {'children': 0,
#   'days_employed': 336777.31338249147,
#   'dob_years': 58.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 15791.867,
#   'purpose': 'property'},
#  964: {'children': 2,
#   'days_employed': 2587.609250387033,
#   'dob_years': 38.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 19347.007,
#   'purpose': 'property'},
#  965: {'children': 0,
#   'days_employed': 5497.9116786264185,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17616.09,
#   'purpose': 'car'},
#  966: {'children': 0,
#   'days_employed': 3674.336418335133,
#   'dob_years': 51.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 11216.537,
#   'purpose': 'property'},
#  967: {'children': 0,
#   'days_employed': 376929.0022081409,
#   'dob_years': 64.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'widow / widower',
#   'family_status_id': 2,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 18614.28,
#   'purpose': 'car'},
#  968: {'children': 0,
#   'days_employed': 394372.118413896,
#   'dob_years': 52.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 26094.635,
#   'purpose': 'car'},
#  969: {'children': 0,
#   'days_employed': 634.6318001449089,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 30534.614,
#   'purpose': 'property'},
#  970: {'children': 0,
#   'days_employed': 369426.4578675727,
#   'dob_years': 58.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 9948.497,
#   'purpose': 'property'},
#  971: {'children': 0,
#   'days_employed': 343209.3742339881,
#   'dob_years': 52.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 13731.848,
#   'purpose': 'car'},
#  972: {'children': 0,
#   'days_employed': 2561.371902929041,
#   'dob_years': 52.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 24655.897,
#   'purpose': 'car'},
#  973: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 49.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  974: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 60.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  975: {'children': 2,
#   'days_employed': 1229.3914171188703,
#   'dob_years': 31.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 17190.878,
#   'purpose': 'car'},
#  976: {'children': 0,
#   'days_employed': 3886.288011903037,
#   'dob_years': 63.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 29937.559,
#   'purpose': 'education'},
#  977: {'children': 0,
#   'days_employed': 2203.0785446761247,
#   'dob_years': 47.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 37799.108,
#   'purpose': 'wedding'},
#  978: {'children': 3,
#   'days_employed': nan,
#   'dob_years': 28.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  979: {'children': 2,
#   'days_employed': 1830.2264432737245,
#   'dob_years': 35.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 65940.37299999999,
#   'purpose': 'property'},
#  980: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 53.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  981: {'children': 0,
#   'days_employed': 400820.11155372026,
#   'dob_years': 57.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 31986.753,
#   'purpose': 'property'},
#  982: {'children': 0,
#   'days_employed': 979.1529300073108,
#   'dob_years': 61.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 48619.955,
#   'purpose': 'car'},
#  983: {'children': 1,
#   'days_employed': 1310.1702084085346,
#   'dob_years': 43.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 35993.405,
#   'purpose': 'property'},
#  984: {'children': 0,
#   'days_employed': 368963.0449150355,
#   'dob_years': 54.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 7757.068,
#   'purpose': 'property'},
#  985: {'children': 1,
#   'days_employed': 553.7348129020858,
#   'dob_years': 29.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 22037.556,
#   'purpose': 'education'},
#  986: {'children': 0,
#   'days_employed': 2316.335967950379,
#   'dob_years': 59.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 52066.415,
#   'purpose': 'education'},
#  987: {'children': 0,
#   'days_employed': 378663.55545998726,
#   'dob_years': 66.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'M',
#   'income_type': 'retiree',
#   'debt': 0,
#   'total_income': 19434.458,
#   'purpose': 'property'},
#  988: {'children': 0,
#   'days_employed': nan,
#   'dob_years': 32.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'property'},
#  989: {'children': 1,
#   'days_employed': 1283.62811376817,
#   'dob_years': 30.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 22673.422,
#   'purpose': 'education'},
#  990: {'children': 1,
#   'days_employed': 1584.3207916113313,
#   'dob_years': 47.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'F',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 31159.689,
#   'purpose': 'wedding'},
#  991: {'children': 1,
#   'days_employed': nan,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': nan,
#   'purpose': 'education'},
#  992: {'children': 1,
#   'days_employed': 2235.141800463776,
#   'dob_years': 26.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'unmarried',
#   'family_status_id': 4,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 15192.924,
#   'purpose': 'car'},
#  993: {'children': 1,
#   'days_employed': 1380.9331038118733,
#   'dob_years': 39.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'civil partnership',
#   'family_status_id': 1,
#   'gender': 'M',
#   'income_type': 'employee',
#   'debt': 1,
#   'total_income': 24839.71,
#   'purpose': 'wedding'},
#  994: {'children': 0,
#   'days_employed': 3197.744727476974,
#   'dob_years': 38.0,
#   'education': "bachelor's degree",
#   'education_id': 0,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 0,
#   'total_income': 38634.174,
#   'purpose': 'education'},
#  995: {'children': 1,
#   'days_employed': 4794.7151187900845,
#   'dob_years': 43.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 11374.623,
#   'purpose': 'property'},
#  996: {'children': 0,
#   'days_employed': 276.99308570749423,
#   'dob_years': 43.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 16777.963,
#   'purpose': 'education'},
#  997: {'children': 0,
#   'days_employed': 2005.5959608215944,
#   'dob_years': 40.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'M',
#   'income_type': 'business',
#   'debt': 0,
#   'total_income': 32459.086,
#   'purpose': 'property'},
#  998: {'children': 0,
#   'days_employed': 10806.501744107814,
#   'dob_years': 46.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'divorced',
#   'family_status_id': 3,
#   'gender': 'F',
#   'income_type': 'employee',
#   'debt': 0,
#   'total_income': 25556.533,
#   'purpose': 'education'},
#  999: {'children': 1,
#   'days_employed': 2115.5352490039795,
#   'dob_years': 42.0,
#   'education': 'secondary education',
#   'education_id': 1,
#   'family_status': 'married',
#   'family_status_id': 0,
#   'gender': 'F',
#   'income_type': 'civil servant',
#   'debt': 1,
#   'total_income': 12663.626,
#   'purpose': 'property'},
#  ...}

# %%
df['days_employed'].describe()
# Out:
# count     19351.000000
# mean      63046.497661
# std      140827.311974
# min      -18388.949901
# 25%       -2747.423625
# 50%       -1203.369529
# 75%        -291.095954
# max      401755.400475
# Name: days_employed, dtype: float64

# %%
df['total_income'].describe()
# Out:
# count     19351.000000
# mean      26787.568355
# std       16475.450632
# min        3306.762000
# 25%       16488.504500
# 50%       23202.870000
# 75%       32549.611000
# max      362496.645000
# Name: total_income, dtype: float64

# %% [markdown]
# ### Memperbaiki nilai yang hilang di `total_income`

# %% [markdown]
# Saya akan memperbaiki nilai yang hilang di kolom total income terlebih dulu. Pertama, saya membuat fungsi yang mengategorikan usia, dengan mengategorikannya, akan lebih rapi dan mudah untuk dilihat. Juga karena nilai di kolom dob_years sama pentingnya demgan kolom lain.
#
# Saya akan memulai dengan mengatasi total nilai pendapatan yang hilang. Pertama, membuat kategori usia untuk nasabah. Buat kolom baru yang memuat kategori usia. Strategi ini dapat membantu untuk menghitung total nilai pendapatan.

# %%
# Mari kita tulis sebuah fungsi untuk menghitung kategori usia
def age_group(age):
  if age <= 30:
    return 'young adult'
  elif age <= 40:
    return 'adult'
  elif age <= 50:
    return 'middle aged'
  elif age <= 60:
    return 'old'
  else:
    return 'elder'

# %% [markdown]
# Disini saya membuat fungsi untuk mengategorikan usia. Jika orang tersebut berusia kurang dari sama dengan 30 tahun,
# maka ia termasuk dalam kategori 'young adult'.
# Jika ia berusia kurang dari sama dengan 40 tahun, maka ia termasuk dalam kategori 'adult' dan seterusnya.

# %%
# Lakukan pengujian untuk melihat apakah fungsi Anda bekerja atau tidak
print(age_group(35))
print(age_group(47))
print(age_group(65))
# Out:
# adult
# middle aged
# elder

# %%
# Buatlah kolom baru berdasarkan fungsi
df['age_group'] = df['dob_years'].apply(age_group)

# %%
# Periksa bagaimana nilai di dalam kolom baru
df.head(5)
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0  340266.072047       53.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
#
#      purpose    age_group
# 0   property  middle aged
# 1        car        adult
# 2   property        adult
# 3  education        adult
# 4    wedding          old

# %% [markdown]
# Selanjutnya saya membuat tabel yang hanya memuat data tanpa nilai yang hilang. Data ini akan digunakan untuk memperbaiki nilai yang hilang.

# %%
# Buat tabel tanpa nilai yang hilang dan tampilkan beberapa barisnya untuk memastikan semuanya berjalan dengan baik
df_not_null = df[df['total_income'].notnull()].reset_index(drop=True)
df_not_null.head(10)
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0  340266.072047       53.0  secondary education             1
# 5         0     926.185831       27.0    bachelor's degree             0
# 6         0    2879.202052       43.0    bachelor's degree             0
# 7         0     152.779569       50.0  secondary education             1
# 8         2    6929.865299       35.0    bachelor's degree             0
# 9         0    2188.756445       41.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#      purpose    age_group
# 0   property  middle aged
# 1        car        adult
# 2   property        adult
# 3  education        adult
# 4    wedding          old
# 5   property  young adult
# 6   property  middle aged
# 7  education  middle aged
# 8    wedding        adult
# 9   property  middle aged

# %%
# Perhatikan nilai rata-rata untuk pendapatan berdasarkan faktor yang telah Anda identifikasi
df.groupby(['income_type'])['total_income'].mean()
# Out:
# income_type
# business                       32386.793835
# civil servant                  27343.729582
# employee                       25820.841683
# entrepreneur                   79866.103000
# paternity / maternity leave     8612.661000
# retiree                        21940.394503
# student                        15712.260000
# Name: total_income, dtype: float64

# %%
# Perhatikan nilai median untuk pendapatan berdasarkan faktor yang telah Anda identifikasi
df.groupby(['income_type'])['total_income'].median()
# Out:
# income_type
# business                       27577.2720
# civil servant                  24071.6695
# employee                       22815.1035
# entrepreneur                   79866.1030
# paternity / maternity leave     8612.6610
# retiree                        18962.3180
# student                        15712.2600
# Name: total_income, dtype: float64

# %% [markdown]
# Setelah mencoba beberapa perbandingan, saya memutuskan bahwa perbandingan antara 'income_type' dan 'total_income' adalah yang paling ideal. Saat mengajukan kredit, biasanya anda akan ditanya mengenai pekerjaan dan berapa penghasilan anda. Kedua hal ini memegang peran penting untuk keputusan pihak bank sebagai pemberi kredit.

# %% [markdown]
# Saya menggunakan median karena saat mengecek dengan menggunakan boxplot, distribusi nilai pada sebelah kiri lebih menonjol atau miring ke sebelah kiri. Untuk itu, menggunakan median akan lebih baik untuk mengatasi nilai pada 'total_income'.

# %%
#  Tulis fungsi yang akan kita gunakan untuk mengisi nilai yang hilang
def fill_missing_value (dataframe, agg_column, value_column):
    grouped_values = dataframe.groupby(agg_column)[value_column].median().reset_index()
    size = len(grouped_values)
    for i in range(size):
        group = grouped_values[agg_column][i]
        value = grouped_values[value_column][i]
        dataframe.loc[(dataframe[agg_column]==group) & (dataframe[value_column].isna()), value_column] = value
    return dataframe

new_df = fill_missing_value(df, 'income_type', 'total_income')

# %% [markdown]
# Untuk mengisi nilai yang hilang, saya membuat fungsi seperti di atas. Saya menggunakan median karena pada saat menggunakan boxplot,
# bagian data cenderung miring ke kiri. Kolom yang digunakan pada 'group' adalah 'income_type' yang akan diagregasi dan pada 'value' menggunakan kolom 'total_income'.
# Kemudian reset_index dilakukan agar menjadi kolom.
#
# for i in range digunakan untuk proses looping jika ada missing value pada kolom 'income_type' maka akan diisi dengan value pada 'total_income'.
# Dan pada baris dataframe.loc dilakukan looping dengan kolom yg di agregasi dan jika ada nilai pada kolom pada value yg kosong,
# maka akan diisi dari hasil value [(dataframe[agg_column]==group) & (dataframe[value_column].isna()), value_column].
# Kemudian reset_index dilakukan agar menjadi kolom.

# %%
# Memeriksa bagaimana nilai di dalam kolom baru
df.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %%
# Terapkan fungsi tersebut ke setiap baris
new_df = fill_missing_value(df, 'income_type', 'total_income')

# %%
# Periksa apakah kita mendapatkan kesalahan
print(new_df['total_income'].isna().sum())
# Out:
# 0

# %%
# Periksa jumlah entri di kolom
new_df['total_income'].count()
# Out:
# 21525

# %% [markdown]
# ###  Memperbaiki nilai di `days_employed`

# %% [markdown]
# Saya menggunakan median karena saat mengecek dengan menggunakan boxplot, distribusi nilai pada sebelah kiri lebih menonjol atau miring ke sebelah kiri. Untuk itu, menggunakan median akan lebih baik untuk mengatasi nilai pada 'days_employed'.

# %%
# Distribusi median dari `days_employed` berdasarkan parameter yang Anda identifikasi
df.groupby(['education'])['days_employed'].median()
# Out:
# education
# bachelor's degree      1895.747795
# graduate degree        5660.057032
# primary education      3043.933615
# secondary education    2392.483500
# some college           1209.128083
# Name: days_employed, dtype: float64

# %%
# Distribusi rata-rata dari `days_employed` berdasarkan parameter yang Anda identifikasi
df.groupby(['education'])['days_employed'].mean()
# Out:
# education
# bachelor's degree       42375.409174
# graduate degree        121323.630206
# primary education      130340.426349
# secondary education     76413.822372
# some college            20656.632017
# Name: days_employed, dtype: float64

# %%
# Mari tulis fungsi yang menghitung rata-rata atau median (tergantung keputusan Anda) berdasarkan parameter yang Anda identifikasi
def fill_missing_value (dataframe, agg_column, value_column):
    grouped_values = dataframe.groupby(agg_column)[value_column].median().reset_index()
    size = len(grouped_values)
    for i in range(size):
        group = grouped_values[agg_column][i]
        value = round(grouped_values[value_column][i], 0)
        dataframe.loc[(dataframe[agg_column]==group) & (dataframe[value_column].isna()), value_column] = value
    return dataframe

new_df = fill_missing_value(df, 'education', 'days_employed')

# %% [markdown]
# Untuk mengisi nilai yang hilang, saya membuat fungsi seperti di atas. Sama seperti mengisi nilai hilang pada 'days_employed',
# saya menggunakan median karena pada saat menggunakan boxplot,
# bagian data cenderung miring ke kiri. Kolom yang digunakan pada 'group' adalah 'education' yang akan diagregasi dan pada 'value' menggunakan kolom 'days_employed'.
# Kemudian reset_index dilakukan agar menjadi kolom.
#
# for i in range digunakan untuk proses looping jika ada missing value pada kolom 'education' maka akan diisi dengan value pada 'days_employed'.
# Dan pada baris dataframe.loc dilakukan looping dengan kolom yg di agregasi dan jika ada nilai pada kolom pada value yg kosong,
# maka akan diisi dari hasil value [(dataframe[agg_column]==group) & (dataframe[value_column].isna()), value_column].

# %%
# Periksa apakah fungsi Anda dapat bekerja
new_df_test
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42    bachelor's degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 0                married                 0      F    employee     0
# 1                married                 0      F    employee     0
# 2                married                 0      M    employee     0
# 3                married                 0      M    employee     0
# 4      civil partnership                 1      F     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21520  civil partnership                 1      F    business     0
# 21521            married                 0      F     retiree     0
# 21522  civil partnership                 1      M    employee     1
# 21523            married                 0      M    employee     1
# 21524            married                 0      F    employee     0
#
#        total_income                  purpose total_income_category
# 0         40620.102    purchase of the house                  high
# 1         17932.802             car purchase                  high
# 2         23341.752    purchase of the house                  high
# 3         42820.568  supplementary education                  high
# 4         25378.572        to have a wedding                  high
# ...             ...                      ...                   ...
# 21520     35966.698     housing transactions                  high
# 21521     24959.969        purchase of a car                  high
# 21522     14347.610                 property                  high
# 21523     39054.888        buying my own car                  high
# 21524     13127.587             to buy a car                  high
#
# [21525 rows x 13 columns]

# %%
# Terapkan fungsi ke days_employed
new_df = fill_missing_value(df, 'education', 'days_employed')

# %%
# Periksa apakah fungsi Anda bekerja
print(new_df['days_employed'].isna().sum())
# Out:
# 0

# %%
new_df['days_employed'].count()# Periksa entri di semua kolom - pastikan kita memperbaiki semua nilai yang hilang
# Out:
# 21525

# %%
df.isna().sum() 
# Chamdani
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ## Pengkategorian Data
#
# Untuk menjawab pertanyaan dan menguji hipotesis, saya akan bekerja dengan data yang telah dikategorikan.

# %%
# Tampilkan nilai data yang Anda pilih untuk pengkategorian
df['purpose'].value_counts()
# Out:
# property     10616
# car           4277
# education     3973
# wedding       2318
# Name: purpose, dtype: int64

# %% [markdown]
# [Mari kita memeriksa nilai unik]

# %%
# Periksa nilai unik
df['purpose'].unique()
# Out:
# array(['property', 'car', 'education', 'wedding'], dtype=object)

# %% [markdown]
# Inilah kelompok utama apakah yang dapat diidentifikasi berdasarkan nilai uniknya.
# Ada 4 tujuan pengajuan kredit yaitu property, car, education dan wedding.
# Kita akan mengkategorikan data kita berdasarkan topik ini.

# %%
# Mari kita tulis sebuah fungsi untuk mengategorikan data berdasarkan topik umum
def purpose_categorize(purpose):
  if 'hous' in purpose or 'prop' in purpose or 'real est' in purpose:
    return 'investment'
  elif 'car' in  purpose:
    return 'asset'
  else:
    return 'personal'

# %%
# Buat kolom yang memuat kategori dan hitung nilainya
df['purpose_category'] = df['purpose'].apply(purpose_categorize)
df['purpose_category'].value_counts()
# Out:
# investment    10616
# personal       6291
# asset          4277
# Name: purpose_category, dtype: int64

# %%
# Lihat semua data numerik di kolom yang Anda pilih untuk pengkategorian
df['total_income'].value_counts()
# Out:
# 22815.1035    1105
# 27577.2720     509
# 18962.3180     414
# 24071.6695     147
# 17312.7170       2
#               ...
# 45484.1090       1
# 27715.4580       1
# 23834.5340       1
# 26124.6130       1
# 41428.9160       1
# Name: total_income, Length: 19350, dtype: int64

# %% [markdown]
# # Dapatkan kesimpulan statistik untuk kolomnya
# Total income yang memiliki rentang yang beragam dapat disimpulkan bahwa lebih banyak orang yang memiliki penghasilan tinggi yang mengajukan kredit

# %% [markdown]
# Rentang kategori ini dibagi menjadi 3 yaitu low, medium, high. Membagi pendapatan menjadi 3 rentang akan memudahkan untuk melihat mana tingkat pendapatan rendah, sedang dan tinggi. 3 rentang dirasa cukup dan sederhana.

# %%
# Buat fungsi yang melakukan pengkategorian menjadi kelompok numerik yang berbeda berdasarkan rentang
def total_income_category(total_income):
    if total_income < 10000:
      return 'low'
    elif total_income >= 10000 and total_income <= 1000000:
      return 'medium'
    else:
      return 'high'

# %%
# Buat kolom yang memuat kategori
df['total_income_category'] = new_df['total_income'].apply(total_income_category)

# %%
# Hitung setiap nilai kategori untuk melihat pendistribusiannya
df['total_income_category'].value_counts()
# Out:
# high      20500
# low         926
# medium       99
# Name: total_income_category, dtype: int64

# %%
df['total_income_category'].unique()
# Out:
# array(['high', 'low', 'medium'], dtype=object)

# %% [markdown]
# ## Memeriksa hipotesis

# %% [markdown]
# **Apakah terdapat korelasi antara memiliki anak dengan melakukan pelunasan tepat waktu?**

# %%
# Periksa data anak dan data pelunasan tepat waktu
total_credit_children = df.groupby('children')['debt'].count()
debt_credit_children = df.groupby('children')['debt'].sum()

# %%
# Hitung gagal bayar berdasarkan jumlah anak
ratio_children = debt_credit_children/total_credit_children
ratio_children.sort_values(ascending=False)
# Out:
# children
#  20    0.105263
#  4     0.097561
#  2     0.094404
#  1     0.092154
#  3     0.081818
#  0     0.075129
# -1     0.021277
#  5     0.000000
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan cek data dan perhitungan yang dilakukan, calon peminjam yang memiliki 4 anak memiliki tingkat kegagalan membayar paling tinggi yaitu sekitar 9,7%. Sedangkan untuk calon peminjam yang belum/tidak memiliki anak, memiliki tingkat kegagalan membayar sebanyak sekitar 7,4%. Di luar dugaan, calon peminjam yang memiliki 5 anak, memiliki tingkat kegagalan membayar sebanyak 0%.

# %% [markdown]
# **Apakah terdapat korelasi antara status keluarga dengan pelunasan tepat waktu?**

# %%
# Periksa data status keluarga dan pelunasan tepat waktu
total_credit_family_status = df.groupby('family_status')['debt'].count()
debt_credit_family_status = df.groupby('family_status')['debt'].sum()

# %%
# Hitung gagal bayar berdasarkan status keluarga
ratio_family = debt_credit_family_status/total_credit_family_status
ratio_family.sort_values(ascending=False)
# Out:
# family_status
# unmarried            0.097405
# civil partnership    0.092890
# married              0.075202
# divorced             0.071130
# widow / widower      0.065625
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan cek data dan perhitungan yang dilakukan, hasil masing-masing tiap status keluarga memiliki tingkat kegagalan pembayaran yang tinggi. Namun menurut saya sebenarnya status keluarga tidak memiliki korelasi dengan tepat waktu atau tidaknya pelunasan.

# %% [markdown]
# **Apakah terdapat korelasi antara tingkat pendapatan dengan membayar kembali tepat waktu?**

# %%
# Periksa data tingkat pendapatan dan pelunasan tepat waktu
total_credit_income = df.groupby('total_income_category')['debt'].count()
debt_credit_income = df.groupby('total_income_category')['debt'].sum()


# Hitung gagal bayar berdasarkan tingkat pendapatan
ratio_income = debt_credit_income/total_credit_income
ratio_income.sort_values(ascending=False)
# Out:
# total_income_category
# high      0.081805
# low       0.062635
# medium    0.060606
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# Hasil dari perhitungan menunjukkan calon peminjam yang memiliki pendapatan rendah, sedang dan tinggi sama-sama memiliki tingkat kegagalan membayar yang tidak selisih jauh.
#
# Menurut saya, tentu ada korelasi antara tingkat pendapatan dengan pelunasan tepat waktu, karena tentunya penghasilan lah yang akan digunakan untuk membayar kredit.

# %% [markdown]
# **Bagaimana tujuan kredit memengaruhi tingkat gagal bayar?**

# %%
# Periksa persentase tingkat gagal bayar untuk setiap tujuan kredit dan lakukan penganalisisan
total_purpose_credit = df.groupby('purpose')['debt'].count()
debt_credit_purpose = df.groupby('purpose')['debt'].sum()
ratio_purpose = total_purpose_credit/debt_credit_purpose
ratio_purpose.sort_values(ascending=False)
# Out:
# purpose
# property     13.861893
# wedding      12.623656
# education    10.870270
# car          10.707196
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan tujuan kredit, calon peminjam yang berhubungan dengan bidang property memiliki tingkat kegagalan membayar paling tinggi dibandingkan dengan tujuan kredit lainnya, yaitu sekitar 13%. Tentu tidak mengherankan karena harga property yang memang terbilang mahal. Walaupun persentase tingkat kegagalan membayar pada tujuan kredit lainnya memiliki selisih tidak begitu jauh dengan property.

# %% [markdown]
# # Kesimpulan umum
#
#
# Data ini memiliki nilai yang hilang, nilai yang mempunyai banyak kemiripan dan juga kesalahan penulisan. Hal pertama yang harus dilakukan tentunya adalah pengecekan data agar dapat mengetahui langkah apa yang harus dilakukan setelahnya, seperti memperbaiki kesalahan penulisan, mengelompokkan data yang memiliki kemiripan seperti pada kolom tujuan kredit.
#
#
# Apakah terdapat korelasi antara memiliki anak dengan melakukan pelunasan tepat waktu?
# Bisa jadi ada bisa jadi tidak, seperti yang bisa dilihat pada data perhitungan, orang yang tidak/belum memiliki anak memiliki tingkat gagal membayar sebanyak 7,4% dan angka ini tidak selisih jauh dengan tingkat gagal peminjam yang telah memiliki anak yaitu sekitar 8-9%.
#
#
# Apakah terdapat korelasi antara status keluarga dengan pelunasan tepat waktu?
# Untuk hal ini saya merasa tidak ada korelasinya. Status keluarga seseorang tidak terlalu berpengaruh terhadap tepat waktunya atau tidak untuk membayar pelunasan. Hal ini masih berkaitan dengan tingkat kegagalan peminjam yang belum/tidak memiliki anak dan yang sudah memiliki anak.
#
#
# Apakah terdapat korelasi antara tingkat pendapatan dengan membayar kembali tepat waktu?
# Seperti yang sudah ditulis di atas, menurut saya ini tingkat pendapatan tentunya sangat memiliki korelasi dengan tingkat kegagalan dalam pembayaran. Hal ini dikarenakan peminjam tentunya akan membayar pinjaman dengan penghasilannya. Jika peminjam memiliki penghasilan yang rendah, tentunya akan mengalami kesulitan yang lebih tinggi dalam membayar kredit dibandingkan dengan peminjam yang memiliki penghasilan tinggi.
